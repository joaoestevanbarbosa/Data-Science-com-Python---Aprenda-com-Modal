# %% [markdown]
# **# Data Science com Python**
# ## Módulo 1 - Introdução ao Python

# %% [markdown]
# Nós gostariamos de te dar as boas vindas ao nosso curso de Data Science com Python.
# Este curso foi desenhado para ser uma imersão no mundo de Data Sciente, unindo o fundamental da teoria com a prática em Python.
# Ao longo dos móudlos desse curso, você vai mergulhar nos principais aspector do mundo de Data Science e como desenvolvê-los usando a programação em Python.

# %% [markdown]
# <center><img src = "https://upload.wikimedia.org/wikipedia/commons/1/1f/Python_logo_01.svg" width = "500">

# %% [markdown]
# Prática Hello World!

# %%
#Função print para imprimir na tela a mensagem entre aspas
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## 1. Variáveis vs Objetos

# %% [markdown]
# ### 1.1 Tipos de Variáveis

# %% [markdown]
# integer (int) : 2
#
# float: 1.45789
#
# string (str): 'PETR4'
#
# boolean (bool) True or False

# %%
b = 5

# %%
type(b)
# Out:
# int

# %%
ativo = 'PETR4'

# %%
type(ativo)
# Out:
# str

# %%
b == ativo
# Out:
# False

# %% [markdown]
# # 2. Operadores Aritméticos
# * Soma +
#
# * Subtração -
#
# * Multiplicação *
#
# * Divisão /
#
# * Divisão (parte inteira) //
#
# * Resto da divisão %
#
# * Potência **

# %% [markdown]
# Exemplo
#
# Qual o tamanho da minha posição em PETR4 dados o número de papéis que comprei e a cotação atual?

# %%
cotacao = 33.32
papeis = 100

# %%
patrimonio = cotacao*papeis

# %%
patrimonio
# Out:
# 3332.0

# %% [markdown]
# Qual o preco atual?

# %%
patrimonio/papeis
# Out:
# 33.32

# %% [markdown]
# Exemplo com VALE3 - qual o número de papéis que posso comprar?

# %%
carteira = 4000

# %%
vale3 = 50.32

# %%
#// para pegar divisão inteira
carteira//vale3
# Out:
# 79.0

# %% [markdown]
# Resto da divisão

# %%
10%3
# Out:
# 1

# %% [markdown]
# Potenciação **

# %%
2**3
# Out:
# 8

# %% [markdown]
# ## 3. Operadores lógicos

# %% [markdown]
# ### 3.1 Operadores comparativos

# %% [markdown]
# * Igualdade ==
#
# * Diferença !=
#
# * Menor <
#
# * Maior >
#
# * Menor ou igual <=
#
# * Maior ou igual >=

# %%
carteira > vale3
# Out:
# True

# %%
cotacao > papeis
# Out:
# False

# %% [markdown]
# ## 3.2 Operadores condicionais
#
# * and
#
# * or

# %%
cotacao < papeis and carteira < vale3
# Out:
# False
